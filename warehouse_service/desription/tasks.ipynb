# %% [markdown]
# ## Задачи по проекту

# %% [markdown]
# #### 1. Добавить разделение на данные для админов и обычных пользователей
# **Приоритет**:  P4\
# **Подробное описание**:\
# Будет добавлено позже

# %% [markdown]
# #### 2. Добавить получение данных по категории, цене, объёму (для термосов)
# **Приоритет**:  P4\
# **Подробное описание**:\
# Сделать через вызов уже существующей функции get_products передавая туда необходимые параметры

# %% [markdown]
# #### 3. Изменить вывод при получении данных так, чтобы у нас выводилось общее количество и потом количество на каждом из складов
# **Приоритет**:  P4\
# **Подробное описание**:\
# Будет добавлено позже

# %% [markdown]
# #### 4. Добавить изменение товара, в основном речь идет о количестве
# **Приоритет**:  P4\
# **Подробное описание**:\
# Будет добавлено позже

# %% [markdown]
# #### 5. Добавить добавление нового товара
# **Приоритет**:  P4\
# **Подробное описание**:\
# Будет добавлено позже

# %% [markdown]
# #### 6. Добавить возможность резервирования товара
# **Приоритет**:  P4\
# **Подробное описание**:\
# То есть к нам пришел закза с артикулом таким *** и мы смотрим если есть товар на складе, тогда резервируем его и в следующие разы когда смотрим наличие товара нам выдаётся: сколько товаров
# - всего
# - зарезервировано
# - сколько доступно

# %% [markdown]
# #### 7. Добавить получение пути (ссылки) на фото в get all products и get product by id
# **Приоритет**:  P4\
# **Подробное описание**:\
# У нас теперь фото хранится на удаленном сервере, а в бд храним путь (ссылку) к фото, поэтому нам надо получать её из таблицы products.

# %% [markdown]
# #### 8. Добавить возможность изменения количества товара в бд на каком-нибудь складе by id товара
# **Приоритет**:  P4\
# **Подробное описание**:\
# Запросить id товара, id склада и обновить (уменьшить/увеличить количество товара)

# %% [markdown]
# #### 9. Сделать разделение товаров по категориям можно с помощью простой нумерации категорий то есть у нас есть id товара 000000 где первые 2 цифры 00|0000 это категория товара (то есть у нас есть возможность добавить 100 категорий товара), а остальные это уже id самого товара, один только вопрос сможем ли мы для этого использовать primary key или нам придётся использовать sku (артикул) товара
# **Приоритет**:  P4\
# **Подробное описание**:\
