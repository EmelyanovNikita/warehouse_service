# %% [markdown]
# ## Задачи по проекту

# %% [markdown]
# #### 1. Добавить разделение на данные для админов и обычных пользователей
# **Приоритет**:  P4\
# **Подробное описание**:\
# Будет добавлено позже

# %% [markdown]
# #### 2. Добавить получение данных по категории, цене, объёму (для термосов)
# **Приоритет**:  P4\
# **Подробное описание**:\
# Будет добавлено позже

# %% [markdown]
# #### 3. Изменить вывод при получении данных так, чтобы у нас выводилось общее количество и потом количество на каждом из складов
# **Приоритет**:  P4\
# **Подробное описание**:\
# Будет добавлено позже

# %% [markdown]
# #### 4. Добавить изменение товара, в основном речь идет о количестве
# **Приоритет**:  P4\
# **Подробное описание**:\
# Будет добавлено позже

# %% [markdown]
# #### 5. Добавить добавление нового товара
# **Приоритет**:  P4\
# **Подробное описание**:\
# Будет добавлено позже

# %% [markdown]
# #### 6. Добавить возможность резервирования товара
# **Приоритет**:  P4\
# **Подробное описание**:\
# То есть к нам пришел закза с артикулом таким *** и мы смотрим если есть товар на складе, тогда резервируем его и в следующие разы когда смотрим наличие товара нам выдаётся: сколько товаров
# - всего
# - зарезервировано
# - сколько доступно
